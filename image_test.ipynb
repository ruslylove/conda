# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('Stone-Texture.jpg',2)

kernel = np.ones((30,30),np.float32)/(30*30)
dst = cv2.filter2D(img,-1,kernel)

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
len(img)
# Out:
# 392

# %%
plt.subplot(121), plt.plot(img[250][:])
plt.subplot(122),plt.plot(dst[250][:])
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f92812b3fa0>,
#  [<matplotlib.lines.Line2D at 0x7f9282859400>])

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-e075c10892b5> in <module>
# ----> 1 ret, bw_img = cv2.threshold(img,dst,255,cv2.THRESH_BINARY)
#
# TypeError: Argument 'thresh' can not be treated as a double
